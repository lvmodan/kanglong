# %%
# -*- coding: utf-8 -*-

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import bisect

import warnings
warnings.filterwarnings("ignore")

# %%
#指定日期的指数PE(市值加权)
def get_index_pe_date(index_code,date):
    stocks = get_index_stocks(index_code, date)
    q = query(valuation).filter(valuation.code.in_(stocks))
    df = get_fundamentals(q, date)
    df = df[df['pe_ratio'] > 0]
    if len(df) > 0:
        #pe = len(df)/sum([1/p if p>0 else 0 for p in df.pe_ratio])
        #pe = df['pe_ratio'].size/(1/df['pe_ratio']).sum()
        pe = df['circulating_market_cap'].sum()/(df['circulating_market_cap']/df['pe_ratio']).sum()
        return pe
    else:
        return float('NaN')

# %%
#指定日期的指数PB(市值加权)
def get_index_pb_date(index_code,date):
    stocks = get_index_stocks(index_code, date)
    q = query(valuation).filter(valuation.code.in_(stocks))
    df = get_fundamentals(q, date)
    df = df[df['pb_ratio']>0]
    if len(df)>0:
        #pb = len(df)/sum([1/p if p>0 else 0 for p in df.pb_ratio])
        #pb = df['pb_ratio'].size/(1/df['pb_ratio']).sum()
        pb = df['circulating_market_cap'].sum()/(df['circulating_market_cap']/df['pb_ratio']).sum()
        return pb
    else:
        return float('NaN')

# %%
#指数历史PEPB
def get_index_pe_pb(index_code):
    start='2011-1-1'
    end = pd.datetime.today();
    dates=[]
    pes=[]
    pbs=[]
    for d in pd.date_range(start,end,freq='W'): #频率为周
        dates.append(d)
        pes.append(get_index_pe_date(index_code,d))
        pbs.append(get_index_pb_date(index_code,d))
    d = {
            'PE' : pd.Series(pes, index=dates),
            'PB' : pd.Series(pbs, index=dates)
        }
    PB_PE = pd.DataFrame(d)
    return PB_PE

# %%
all_index = get_all_securities(['index'])

index_choose = [
    '399902.XSHE', # 中证流通
    '000016.XSHG', # 上证50',     #110003.OF 易方达上证50指数
    '000300.XSHG', # :'沪深300',    #000176.OF 嘉实沪深300增强
    '000905.XSHG', # :'中证500',    #000478.OF 建信中证500增强
    '000919.XSHG', #:'300价值',    #310398.OF 申万沪深300价值
    '000922.XSHG', #:'中证红利',   #100032.OF 富国中证红利
    '399702.XSHE', #:'深证F120',   #070023.OF 嘉实深F120基本面联接
    '399978.XSHE', #:'中证医药100',#001550.OF 天弘中证医药100
    '399812.XSHE',  #:'中证养老'    #000968.OF 广发中证养老指数
    '000932.XSHG', # 中证消费
    '399106.XSHE', # 深证综指
    '399316.XSHE', # 巨潮小盘
]

df_pe_pb = pd.DataFrame()
frames =pd.DataFrame()
today = pd.datetime.today()

# %%
for code in index_choose:
    index_name = all_index.ix[code].display_name
    print('正在处理: ', index_name)
    df_pe_pb = get_index_pe_pb(code)

    results=[]
    pe = get_index_pe_date(code, today)
    q_pes = [df_pe_pb['PE'].quantile(i / 10.0)  for i in range(11)]
    idx = bisect.bisect(q_pes, pe)
    quantile = idx - (q_pes[idx] - pe) / (q_pes[idx] - q_pes[idx-1])
    #index_name = all_index.ix[code].display_name
    results.append([index_name,
                    format(pe, '.2f'),
                    format(quantile * 10, '.2f')] +
                    [format(q, '.2f')  for q in q_pes] +
                    [df_pe_pb['PE'].count()])

    pb = get_index_pb_date(code, today)
    q_pbs = [df_pe_pb['PB'].quantile(i / 10.0)  for i in range(11)]
    idx = bisect.bisect(q_pbs, pb)
    quantile = idx - (q_pbs[idx] - pb) / (q_pbs[idx] - q_pbs[idx-1])
    #index_name = all_index.ix[code].display_name
    results.append([index_name,
                    format(pb, '.2f'),
                    format(quantile * 10, '.2f')] +
                    [format(q, '.2f')  for q in q_pbs] +
                    [df_pe_pb['PB'].count()])


    df_pe_pb['10% PE']=q_pes[1]
    df_pe_pb['50% PE']=q_pes[5]
    df_pe_pb['90% PE']=q_pes[9]
    df_pe_pb['10% PB']=q_pbs[1]
    df_pe_pb['50% PB']=q_pbs[5]
    df_pe_pb['90% PB']=q_pbs[9]

    plt.rcParams['font.sans-serif']=['SimHei']
    df_pe_pb.plot(secondary_y=['PB','10% PB','50% PB','90% PB'],
                  figsize=(14,8), title = index_name,
                  style=['k-.', 'k', 'g', 'y', 'r', 'g-.', 'y-.', 'r-.'])

    columns=['名称', '当前估值', '分位点%', '最小估值'] + \
            [format(i * 10, 'd') + '%%' for i in range(1,10)] + \
            ['最大估值' , '数据个数']

    df= pd.DataFrame(data = results,
                     index = ['PE','PB'],
                     columns = columns)
    frames = pd.concat([frames, df])

frames
# Out:
# ('\xe6\xad\xa3\xe5\x9c\xa8\xe5\xa4\x84\xe7\x90\x86: ', u'\u4e2d\u8bc1\u6d41\u901a\u6307\u6570')
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-77568b316859> in <module>()
#       3     index_name = all_index.ix[code].display_name
#       4     print('正在处理: ', index_name)
# ----> 5     df_pe_pb = get_index_pe_pb(code)
#       6
#       7     results=[]
#
# <ipython-input-4-1dbe9653f1b4> in get_index_pe_pb(index_code)
#       8     for d in pd.date_range(start,end,freq='W'): #频率为周
#       9         dates.append(d)
# ---> 10         pes.append(get_index_pe_date(index_code,d))
#      11         pbs.append(get_index_pb_date(index_code,d))
#      12     d = {
#
# <ipython-input-2-7510450f7917> in get_index_pe_date(index_code, date)
#       3     stocks = get_index_stocks(index_code, date)
#       4     q = query(valuation).filter(valuation.code.in_(stocks))
# ----> 5     df = get_fundamentals(q, date)
#       6     df = df[df['pe_ratio'] > 0]
#       7     if len(df) > 0:
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/jqresearch/api.pyc in get_fundamentals(query_object, date, statDate)
#     331         yestoday = datetime.date.today() - datetime.timedelta(days=1)
#     332         date = min(parse_date(date), yestoday)
# --> 333     return jqdata.apis.get_fundamentals(query_object, date=date, statDate=statDate)
#     334
#     335
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/jqdata/apis/db.pyc in get_fundamentals(query_object, date, statDate, sql)
#     859         date = convert_date(date)
#     860     if query_object:
# --> 861         sql = fundamentals_query_to_sql(query_object, date, statDate)
#     862     check_string(sql)
#     863     if is_client_or_ide():  # 客户端
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/jqdata/db_utils.pyc in wrapper(*args, **kwds)
#     209         with warnings.catch_warnings():
#     210             warnings.simplefilter("ignore", category=sa_exc.SAWarning)
# --> 211             return f(*args, **kwds)
#     212     return wrapper
#     213
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/jqdata/apis/db.pyc in fundamentals_query_to_sql(query, date, statDate)
#     849         return fundamentals_non_redundant_query_to_sql(query, date, statDate)
#     850     else:
# --> 851         return fundamentals_redundant_query_to_sql(query, date, statDate)
#     852     pass
#     853
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/jqdata/db_utils.pyc in wrapper(*args, **kwds)
#     209         with warnings.catch_warnings():
#     210             warnings.simplefilter("ignore", category=sa_exc.SAWarning)
# --> 211             return f(*args, **kwds)
#     212     return wrapper
#     213
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/jqdata/apis/db.pyc in fundamentals_redundant_query_to_sql(query, date, statDate)
#     616         return date
#     617
# --> 618     tablenames = get_tables_from_sql(str(query.statement))
#     619     tables = [get_table_class(name) for name in tablenames]
#     620
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/elements.pyc in __str__(self)
#     452             return str(self.compile())
#     453         else:
# --> 454             return unicode(self.compile()).encode('ascii', 'backslashreplace')
#     455
#     456     def __and__(self, other):
#
# <string> in <lambda>(self, bind, dialect, **kw)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/elements.pyc in compile(self, default, bind, dialect, **kw)
#     440             else:
#     441                 dialect = default.StrCompileDialect()
# --> 442         return self._compiler(dialect, bind=bind, **kw)
#     443
#     444     def _compiler(self, dialect, **kw):
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/elements.pyc in _compiler(self, dialect, **kw)
#     446         Dialect."""
#     447
# --> 448         return dialect.statement_compiler(dialect, self, **kw)
#     449
#     450     def __str__(self):
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in __init__(self, dialect, statement, column_keys, inline, **kwargs)
#     451         # dialect.label_length or dialect.max_identifier_length
#     452         self.truncated_names = {}
# --> 453         Compiled.__init__(self, dialect, statement, **kwargs)
#     454
#     455         if (
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in __init__(self, dialect, statement, bind, schema_translate_map, compile_kwargs)
#     217             if self.can_execute:
#     218                 self.execution_options = statement._execution_options
# --> 219             self.string = self.process(self.statement, **compile_kwargs)
#     220
#     221     @util.deprecated("0.7", ":class:`.Compiled` objects now compile "
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in process(self, obj, **kwargs)
#     243
#     244     def process(self, obj, **kwargs):
# --> 245         return obj._compiler_dispatch(self, **kwargs)
#     246
#     247     def __str__(self):
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/annotation.pyc in _compiler_dispatch(self, visitor, **kw)
#      78     def _compiler_dispatch(self, visitor, **kw):
#      79         return self.__element.__class__._compiler_dispatch(
# ---> 80             self, visitor, **kw)
#      81
#      82     @property
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/visitors.pyc in _compiler_dispatch(self, visitor, **kw)
#      79                     raise exc.UnsupportedCompilationError(visitor, cls)
#      80                 else:
# ---> 81                     return meth(self, **kw)
#      82         else:
#      83             # The optimization opportunity is lost for this case because the
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in visit_select(self, select, asfrom, parens, fromhints, compound_index, nested_join_translation, select_wraps_for, lateral, **kwargs)
#    1823
#    1824         text = self._compose_select_body(
# -> 1825             text, select, inner_columns, froms, byfrom, kwargs)
#    1826
#    1827         if select._statement_hints:
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in _compose_select_body(self, text, select, inner_columns, froms, byfrom, kwargs)
#    1907
#    1908         if select._whereclause is not None:
# -> 1909             t = select._whereclause._compiler_dispatch(self, **kwargs)
#    1910             if t:
#    1911                 text += " \nWHERE " + t
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/visitors.pyc in _compiler_dispatch(self, visitor, **kw)
#      91                     raise exc.UnsupportedCompilationError(visitor, cls)
#      92                 else:
# ---> 93                     return meth(self, **kw)
#      94
#      95         _compiler_dispatch.__doc__ = \
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in visit_binary(self, binary, override_operator, eager_grouping, **kw)
#    1080                 raise exc.UnsupportedCompilationError(self, operator_)
#    1081             else:
# -> 1082                 return self._generate_generic_binary(binary, opstring, **kw)
#    1083
#    1084     def visit_mod_binary(self, binary, operator, **kw):
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in _generate_generic_binary(self, binary, opstring, eager_grouping, **kw)
#    1113             opstring + \
#    1114             binary.right._compiler_dispatch(
# -> 1115                 self, eager_grouping=eager_grouping, **kw)
#    1116
#    1117         if _in_binary and eager_grouping:
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/visitors.pyc in _compiler_dispatch(self, visitor, **kw)
#      91                     raise exc.UnsupportedCompilationError(visitor, cls)
#      92                 else:
# ---> 93                     return meth(self, **kw)
#      94
#      95         _compiler_dispatch.__doc__ = \
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in visit_grouping(self, grouping, asfrom, **kwargs)
#     593
#     594     def visit_grouping(self, grouping, asfrom=False, **kwargs):
# --> 595         return "(" + grouping.element._compiler_dispatch(self, **kwargs) + ")"
#     596
#     597     def visit_label_reference(
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/visitors.pyc in _compiler_dispatch(self, visitor, **kw)
#      91                     raise exc.UnsupportedCompilationError(visitor, cls)
#      92                 else:
# ---> 93                     return meth(self, **kw)
#      94
#      95         _compiler_dispatch.__doc__ = \
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in visit_clauselist(self, clauselist, **kw)
#     827             (
#     828                 c._compiler_dispatch(self, **kw)
# --> 829                 for c in clauselist.clauses)
#     830             if s)
#     831
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in <genexpr>((s,))
#     824             sep = OPERATORS[clauselist.operator]
#     825         return sep.join(
# --> 826             s for s in
#     827             (
#     828                 c._compiler_dispatch(self, **kw)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in <genexpr>((c,))
#     827             (
#     828                 c._compiler_dispatch(self, **kw)
# --> 829                 for c in clauselist.clauses)
#     830             if s)
#     831
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/visitors.pyc in _compiler_dispatch(self, visitor, **kw)
#      91                     raise exc.UnsupportedCompilationError(visitor, cls)
#      92                 else:
# ---> 93                     return meth(self, **kw)
#      94
#      95         _compiler_dispatch.__doc__ = \
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in visit_bindparam(self, bindparam, within_columns_clause, literal_binds, skip_bind_expression, **kwargs)
#    1246                 bindparam, within_columns_clause=True, **kwargs)
#    1247
# -> 1248         name = self._truncate_bindparam(bindparam)
#    1249
#    1250         if name in self.binds:
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in _truncate_bindparam(self, bindparam)
#    1303         bind_name = bindparam.key
#    1304         if isinstance(bind_name, elements._truncated_label):
# -> 1305             bind_name = self._truncated_identifier("bindparam", bind_name)
#    1306
#    1307         # add to bind_names for translation
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sqlalchemy/sql/compiler.pyc in _truncated_identifier(self, ident_class, name)
#    1314             return self.truncated_names[(ident_class, name)]
#    1315
# -> 1316         anonname = name.apply_map(self.anon_map)
#    1317
#    1318         if len(anonname) > self.label_length - 6:
#
# KeyboardInterrupt:
